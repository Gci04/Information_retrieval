# %% [markdown]
# # Lab 2. Building inverted index and answering queries
#
# In this lab you are going to implement a standard document processing pipeline and then build a simple search engine based on it: starting from crawling documents, then building an inverted index, answering queries using this index, and organizing it as a simple web server.

# %% [markdown]
# # 1. Preprocessing

# %% [markdown]
# First, we need a unified approach to documents preprocessing, and this class is responsible for it. Complete the code for given functions (most of them are just one-liners) and make sure you pass the tests. Make use of `nltk` library.

# %%
import nltk 
nltk.download('punkt')

class Preprocessor:
    
    def __init__(self):
        self.stop_words = {'a', 'an', 'and', 'are', 'as', 'at', 'be', 'by', 'for', 'from', 'has', 'he', 'in', 'is', 'it', 'its',
                      'of', 'on', 'that', 'the', 'to', 'was', 'were', 'will', 'with'}
        self.ps = nltk.stem.PorterStemmer()

    
    def tokenize(self, text):
        #TODO word tokenize text using nltk lib
        return nltk.word_tokenize(text)

    
    def stem(self, word, stemmer):
        #TODO stem word using provided stemmer
        return stemmer.stem(word)

    
    def is_apt_word(self, word):
        #TODO check if word is appropriate - not a stop word and isalpha, 
        # i.e consists of letters, not punctuation, numbers, dates
        return word.isalpha()

    
    def preprocess(self, text):
        #TODO combine all previous methods together: tokenize lowercased text 
        # and stem it, ignoring not appropriate words
        result = []
        for word in self.tokenize(text.lower()): 
          stammed_word = self.stem(word,self.ps)
          if self.is_apt_word(stammed_word) and word not in self.stop_words :
            result.append(stammed_word)
            
        return result
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## 1.1. Tests ##

# %%
prep = Preprocessor()
text = 'To be, or not to be, that is the question'

assert prep.tokenize(text) == ['To', 'be', ',', 'or', 'not', 'to', 'be', ',', 'that', 'is', 'the', 'question']
assert prep.stem('retrieval', prep.ps) == 'retriev'
assert prep.is_apt_word('qwerty123') is False
assert prep.preprocess(text) == ['or', 'not', 'question']

# %% [markdown]
# # 2. Crawling and Indexing

# %% [markdown]
# ## 2.1 Base classes

# %% [markdown]
# Here are some base classes we will need for writing our indexer. The code from the last lab's solution is given, but note that you will need to change some of it, namely, the `parse` function. The reason is it always makes complete parsing, which we want to avoid when we only need links, for example, or a specific portion of text.

# %%
import requests
from urllib.parse import quote
from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.parse
import os


class Document:

  def __init__(self, url):
     self.url = url

  def download(self):
    try:
      response = requests.get(self.url)
      if response.status_code == 200:
        self.content = response.content
        return True
      else:
        return False
    except:
      return False

  def persist(self, path):
    with open(os.path.join(path, quote(self.url).replace('/', '_')), 'wb') as f:
      f.write(self.content)

class HtmlDocument(Document):

    def normalize(self, href):
      if href is not None and href[:4] != 'http':
          href = urllib.parse.urljoin(self.url, href)
      return href

    def parse(self):
      #TODO change this method
      self.download()
      # print(self.url)

      def tag_visible(element):
          if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
            return False
          if isinstance(element, Comment):
            return False
          return True
      model = BeautifulSoup(self.content)
        
      self.anchors = []
      a = model.find_all('a')
      for anchor in a:
        href = self.normalize(anchor.get('href'))
        # if href[-4:] in ('.pdf', '.mp3', '.avi', '.mp4', '.txt') : 
        #   continue
        text = anchor.text
        self.anchors.append((text, href))

      self.images = []
      i = model.find_all('img')
      for img in i:
        href = self.normalize(img.get('src'))
        self.images.append(href)
        
      texts = model.findAll(text=True)
      visible_texts = filter(tag_visible, texts)  
      self.text = u" ".join(t.strip() for t in visible_texts)

# %% [markdown]
# ## 2.2 Main class

# %% [markdown]
# The main indexer logic is here. We organize it as a crawler generator that adds certain visited pages to inverted index and saves them on disk.
#
# - `crawl_generator_for_index` method crawles the given website doing BFS, starting from `source` within given `depth`. Considers only inner pages (of a form https://www.reuters.com/...) for visiting. To speed up, doesn't consider for visiting pages with content type other than html: '.pdf', '.mp3', '.avi', '.mp4', '.txt'. If encounters an article page (of a form https://www.reuters.com/article/...), saves its content in a file in `collection_path` folder and populates the inverted index calling `index_doc` method. When done, saves on disk three resulting dictionaries:
#     - `doc_urls`, `doc_id:url`
#     - `index`, `term:[collection_frequency, (doc_id_1, doc_freq_1), (doc_id_2, doc_freq_2), ...]`
#     - `doc_lengths`, `doc_id:doc_length`
#
#     `limit` parameter is given for testing - if not `None`, break the loop when number of saved articles exceeds the `limit` and return without writing dictionaries to disk.
#
#
# - `index_doc` method parses and preprocesses the content of a `doc` and adds it to the inverted index. Also keeps track of document lengths in a `doc_lengths` dictionary.
#
#
# **Bonus task \*** In real industrial systems a crawler would pass the links to the dedicated service that would load their contents in a bunch of parallel threads. Implement such a service - get urls as inputs, load page contents in parallel and return filenames on disk, which are then processed by indexer.

# %%
from collections import Counter
from queue import Queue
import pickle
import os
import numpy as np

class Indexer:
  def __init__(self):      
    # dictionaries to populate
    self.doc_urls = {}        
    self.index = {}
    self.doc_lengths = {}
    # preprocessor
    self.prep = Preprocessor()
      
  def crawl_generator_for_index(self, source, depth, collection_path="collection", limit=None):
    q = Queue()
    q.put((source, 0))
    visited = set()
    i = 0
    while not q.empty():
      url, url_depth = q.get()
      if url == None : continue
      if url not in visited and "https://www.reuters.com" in url: #visit only pages from reuters.com
        visited.add(url)
        try:
          doc = HtmlDocument(url)
          if doc.download() == False:
            continue
          doc.parse()
          for a in doc.anchors:
            if url_depth + 1 < depth:
              q.put((a[1], url_depth + 1))
          
          if limit == None and "https://www.reuters.com/article/" in doc.url : #Save document if is an article
            if not os.path.exists(collection_path):
              os.makedirs(collection_path)
            doc.persist(collection_path)
            
          i += 1
          if i == limit : return doc
          yield doc
        except FileNotFoundError as e:
          print("Analyzing", url, "led to FileNotFoundError")
  
  def save_index_config(self):
    """Saves the Indexer configuration componets as pickle files : inverted_index, documents lengths, documents urls

    >>> import pickle
    >>> indxr = Indexer()
    >>> indxr.save_index_config()
    >>> with open('inverted_index.pickle', 'rb') as fp:
    ...   index = pickle.load(fp)
    >>> with open('doc_lengths.pickle', 'rb') as fp:
    ...   doc_len = pickle.load(fp)
    >>> with open('doc_urls.pickle', 'rb') as fp:
    ...   url = pickle.load(fp)
    >>> [doc_len,url,index]
    [{},{},{}]

    """
    print("Saving Indexer Config.....")
    with open('inverted_index.pickle', 'wb') as f:
      pickle.dump(self.index, f, protocol=pickle.HIGHEST_PROTOCOL)

    with open('doc_lengths.pickle', 'wb') as f:
      pickle.dump(self.doc_lengths, f, protocol=pickle.HIGHEST_PROTOCOL)

    with open('doc_urls.pickle', 'wb') as f:
      pickle.dump(self.doc_urls, f, protocol=pickle.HIGHEST_PROTOCOL)

  def index_doc(self, doc, doc_id):
    """Add document to index"""
    self.doc_urls[doc_id] = doc.url
    words = self.prep.preprocess(doc.text)
    self.doc_lengths[doc_id] = len(words)

    count = Counter(words)
    for pair in count.items():
      if pair[0] not in self.index.keys():
        self.index[pair[0]] = [pair[1],(doc_id,pair[1])]
      else:
        self.index[pair[0]][0] += pair[1]
        self.index[pair[0]].append((doc_id,pair[1]))

# %% [markdown]
# ## 2.3. Tests ##

# %% [markdown]
# **In Test where there is a limit & shallow depth, it is possible that the indexer returns empty since it only saves article pages `https://www.reuters.com/article/`** <br>
# To test I save all the pages visited

# %%
indexer = Indexer()
k = 1
for c in indexer.crawl_generator_for_index("https://www.reuters.com/news/us", 3, "test_collection", 5):
  # if "https://www.reuters.com/article/" in c.url:
  print(k, c.url)
  indexer.index_doc(c,k)
  k+=1
indexer.save_index_config()

assert type(indexer.index) is dict
assert type(indexer.index['reuter']) is list
assert type(indexer.index['reuter'][0]) is int
assert type(indexer.index['reuter'][1]) is tuple
# Out:
# 1 https://www.reuters.com/news/us
# 2 https://www.reuters.com/
# 3 https://www.reuters.com/finance
# 4 https://www.reuters.com/finance/markets
# Saving Indexer Config.....

# %% [markdown]
# ## 2.4 Building index

# %%
indexer = Indexer()
k = 1
for c in indexer.crawl_generator_for_index("https://www.reuters.com/", 3, "docs_collection"):
    if "https://www.reuters.com/article/" in c.url:
      print(k, c.url)
      indexer.index_doc(c,k)
      k+=1
indexer.save_index_config()
# Out:
# 1 https://www.reuters.com/article/us-china-health/u-s-and-others-tighten-curbs-on-travel-to-china-as-virus-toll-hits-213-idUSKBN1ZT374
# 2 https://www.reuters.com/article/us-china-health-business-impact/factbox-companies-feel-impact-of-coronavirus-outbreak-in-china-idUSKBN1ZU1LG
# 3 https://www.reuters.com/article/us-china-health-airlines/pilots-flight-attendants-demand-flights-to-china-stop-as-virus-fear-mounts-worldwide-idUSKBN1ZT33W
# 4 https://www.reuters.com/article/us-china-health-masks-safety/to-mask-or-not-to-mask-confusion-spreads-over-coronavirus-protection-idUSKBN1ZU0PH
# 5 https://www.reuters.com/article/us-usa-trump-impeachment/end-draws-near-in-trump-impeachment-trial-as-democrats-likely-to-fall-short-in-vote-idUSKBN1ZU1D2
# 6 https://www.reuters.com/article/us-britain-eu-union/brexit-day-britain-quits-eu-steps-into-transition-twilight-zone-idUSKBN1ZU00R
# 7 https://www.reuters.com/article/us-climatechange-investors-proxy/top-u-s-fund-firms-split-over-new-limits-on-shareholder-votes-idUSKBN1ZU1JW
# 8 https://www.reuters.com/article/us-maryland-coast-guard/u-s-coast-guard-officer-accused-of-plotting-attack-on-democratic-politicians-faces-sentencing-idUSKBN1ZU1EF
# 9 https://www.reuters.com/article/us-pope-argentina/pope-meets-argentina-president-amid-debt-crisis-says-work-for-peace-idUSKBN1ZU1NN?il=0
# 10 https://www.reuters.com/article/us-funds-global-poll/global-funds-prefer-stocks-despite-risks-still-at-play-idUSKBN1ZU1NV?il=0
# 11 https://www.reuters.com/article/us-britain-eu-leaders/eu-seeks-to-put-brave-face-on-brexit-day-warns-uk-of-costs-of-divergence-idUSKBN1ZU10L?il=0
# 12 https://www.reuters.com/article/us-britain-eu-union/brexit-day-britain-quits-eu-steps-into-transition-twilight-zone-idUSKBN1ZU00R?il=0
# 13 https://www.reuters.com/article/us-britain-eu-scotland/scotlands-sturgeon-could-test-power-to-call-consultative-independence-vote-in-court-idUSKBN1ZU16M?il=0
# 14 https://www.reuters.com/article/us-china-health/u-s-and-others-tighten-curbs-on-travel-to-china-as-virus-toll-hits-213-idUSKBN1ZT374?il=0
# 15 https://www.reuters.com/article/us-china-health-business-impact/factbox-companies-feel-impact-of-coronavirus-outbreak-in-china-idUSKBN1ZU1LG?il=0
# 16 https://www.reuters.com/article/us-global-oil/oil-rises-as-who-declares-emergency-but-opposes-travel-ban-idUSKBN1ZU0AC?il=0
# 17 https://www.reuters.com/article/us-china-health-britain-cases/britain-reports-first-two-cases-of-new-coronavirus-idUSKBN1ZU12K?il=0
# 18 https://www.reuters.com/article/us-china-health-beijing/companies-in-beijing-to-resume-work-on-february-10-due-to-virus-fight-government-newspaper-idUSKBN1ZU1MW?il=0
# 19 https://www.reuters.com/article/us-israel-palestinians-violence-un/u-n-aid-agency-fears-u-s-middle-east-plan-will-spark-violence-idUSKBN1ZU1MG?il=0
# 20 https://www.reuters.com/article/us-climatechange-investors-proxy/top-u-s-fund-firms-split-over-new-limits-on-shareholder-votes-idUSKBN1ZU1JW?il=0
# 21 https://www.reuters.com/article/us-china-health-hongkong/hong-kong-leader-rejects-calls-to-close-border-despite-virus-fears-idUSKBN1ZU1K6?il=0
# 22 https://www.reuters.com/article/us-china-health-myanmar/myanmar-turns-back-china-southern-flight-over-coronavirus-fears-government-spokesman-idUSKBN1ZU1KN?il=0
# 23 https://www.reuters.com/article/us-china-health-airlines-factbox/factbox-airlines-suspend-china-flights-due-to-coronavirus-idUSKBN1ZU131?il=0
# 24 https://www.reuters.com/article/us-china-health-siemens-health/siemens-healthineers-supplies-diagnostic-equipment-to-wuhan-hospitals-idUSKBN1ZU1JN?il=0
# 25 https://www.reuters.com/article/us-britain-eu-markets/eu-checks-uk-compliance-with-market-rules-after-brexit-idUSKBN1ZU10U?il=0
# 26 https://www.reuters.com/article/us-oil-prices-poll/opec-curbs-supply-risks-to-buoy-oil-prices-in-2020-reuters-poll-idUSKBN1ZU1DE?il=0
# 27 https://www.reuters.com/article/us-china-health-airlines/pilots-flight-attendants-demand-flights-to-china-stop-as-virus-fear-mounts-worldwide-idUSKBN1ZT33W?il=0
# 28 https://www.reuters.com/article/us-kenya-kenya-airways-coronavirus/east-african-airlines-suspend-china-flights-due-to-coronavirus-idUSKBN1ZU0J2?il=0
# 29 https://www.reuters.com/article/us-people-kobe-bryant-lakers/shadow-of-kobe-bryant-hangs-over-first-lakers-game-since-his-death-idUSKBN1ZU0YT
# 30 https://www.reuters.com/article/us-people-kobe-bryant-helicopter/helicopter-company-in-kobe-bryant-crash-not-certified-to-fly-in-poor-visibility-reports-idUSKBN1ZU0NL
# 31 https://www.reuters.com/article/us-visa-mastercard-stocks/swiping-their-way-higher-visa-mastercard-could-be-the-next-1-trillion-companies-idUSKBN1ZU0JA
# 32 https://www.reuters.com/article/us-football-nfl-superbowl-australia-feat/wishnowsky-rides-australia-punting-pipeline-to-super-bowl-idUSKBN1ZT35O
# 33 https://www.reuters.com/article/idUSKBN1ZU0CU
# 34 https://www.reuters.com/article/us-ukraine-usa-pompeo/pompeo-pledges-support-for-ukraine-as-impeachment-trial-rumbles-idUSKBN1ZU11H
# 35 https://www.reuters.com/article/us-usa-cyber-nso-exclusive/exclusive-fbi-probes-use-of-israeli-firms-spyware-in-personal-and-government-hacks-sources-idUSKBN1ZT38B
# 36 https://www.reuters.com/article/us-global-markets/shares-struggle-for-footing-after-virus-battered-week-idUSKBN1ZU01N
# 37 https://www.reuters.com/article/us-danske-bank-moneylaundering/u-s-could-face-difficulties-sanctioning-danske-over-money-laundering-report-idUSKBN1ZU0ZN
# 38 https://www.reuters.com/article/us-usa-election-healthcare-factbox/where-democratic-presidential-candidates-stand-on-medicare-for-all-idUSKBN1ZU1DY
# 39 https://www.reuters.com/article/us-people-harvey-weinstein/weinstein-accuser-expected-to-testify-about-alleged-rape-relationship-with-producer-idUSKBN1ZU1CY
# 40 https://www.reuters.com/article/us-funds-global-poll/global-funds-prefer-stocks-despite-risks-still-at-play-idUSKBN1ZU1NV
# 41 https://www.reuters.com/article/us-global-oil/oil-rises-as-who-declares-emergency-but-opposes-travel-ban-idUSKBN1ZU0AC
# 42 https://www.reuters.com/article/us-china-health-airlines-factbox/factbox-airlines-suspend-china-flights-due-to-coronavirus-idUSKBN1ZU131
# 43 https://www.reuters.com/article/us-global-forex/trade-linked-currencies-fall-on-worries-about-fallout-from-virus-idUSKBN1ZU069
# 44 https://www.reuters.com/article/us-europe-stocks/european-shares-drop-on-coronavirus-cases-weak-euro-zone-data-idUSKBN1ZU0WR
# 45 https://www.reuters.com/article/us-britain-eu-markets/eu-checks-uk-compliance-with-market-rules-after-brexit-idUSKBN1ZU10U
# 46 https://www.reuters.com/article/us-pope-argentina/pope-meets-argentina-president-amid-debt-crisis-says-work-for-peace-idUSKBN1ZU1NN
# 47 https://www.reuters.com/article/us-britain-eu-leaders/eu-seeks-to-put-brave-face-on-brexit-day-warns-uk-of-costs-of-divergence-idUSKBN1ZU10L
# 48 https://www.reuters.com/article/us-britain-eu-scotland/scotlands-sturgeon-could-test-power-to-call-consultative-independence-vote-in-court-idUSKBN1ZU16M
# 49 https://www.reuters.com/article/us-telecoms-5g-eu-usa/eu-welcomes-pompeos-5g-comments-no-sign-of-change-to-huawei-stance-idUSKBN1ZU1IH
# 50 https://www.reuters.com/article/us-russia-technology-facialrecognition/moscow-court-case-challenges-citys-facial-recognition-use-after-launch-idUSKBN1ZU1HJ
# 51 https://www.reuters.com/article/us-orange-nokia/frances-orange-chooses-nokia-and-ericsson-to-deploy-its-5g-network-at-home-idUSKBN1ZU14I
# 52 https://www.reuters.com/article/us-usa-trump-impeachment-whatnext-factbo/trump-impeachment-what-happens-next-idUSKBN1ZU14B
# 53 https://www.reuters.com/article/us-usa-election-trump/trump-mocks-democrats-revives-border-wall-promise-in-iowa-campaign-speech-idUSKBN1ZU0B4
# 54 https://www.reuters.com/article/us-usa-trump-impeachment/democrats-bid-for-new-trump-impeachment-witnesses-likely-to-fall-short-idUSKBN1ZT18E
# 55 https://www.reuters.com/article/us-astonmartin-stroll/billionaire-lawrence-stroll-shifts-aston-martin-into-the-fast-lane-idUSKBN1ZU0OP
# 56 https://www.reuters.com/article/us-grandvision-m-a-essilorluxottica-eu-e/exclusive-essilorluxotticas-7-2-billion-dutch-deal-faces-full-eu-probe-sources-idUSKBN1ZU143
# 57 https://www.reuters.com/article/us-thyssenkrupp-agm/bidders-value-elevator-unit-at-more-than-16-6-billion-thyssenkrupp-ceo-idUSKBN1ZU0Z7
# 58 https://www.reuters.com/article/us-reuters-editorial-leadership/reuters-editorial-leadership-idUSKBN1KE2SD
# 59 https://www.reuters.com/article/us-amazon-com-results/amazon-holiday-sales-jump-as-one-day-shipping-pays-dividends-stock-up-13-idUSKBN1ZT2XU
# 60 https://www.reuters.com/article/us-oecd-tax/governments-launch-rewrite-of-international-tax-rules-idUSKBN1ZU10F
# 61 https://www.reuters.com/article/us-china-health-manufacturing/frost-on-top-of-snowfall-virus-piles-pressure-on-chinas-industrial-machine-idUSKBN1ZU11O
# 62 https://www.reuters.com/article/us-usa-trump-impeachment/impeachment-trial-turns-to-whistleblower-ahead-of-possible-weekend-finish-idUSKBN1ZT18E
# 63 https://www.reuters.com/article/us-usa-trump-impeachment-schedule/senior-republican-sees-completion-of-impeachment-trial-friday-or-saturday-idUSKBN1ZT2ZZ
# 64 https://www.reuters.com/article/us-usa-trump-impeachment-whatnext/factbox-trump-impeachment-what-happens-next-idUSKBN1ZU02K
# 65 https://www.reuters.com/article/us-china-health-airlines-factbox/factbox-airlines-suspend-china-flights-over-coronavirus-idUSKBN1ZT1RZ
# 66 https://www.reuters.com/article/us-usa-trump-defamation-lawsuit/trump-rape-accuser-seeks-dna-sample-from-u-s-president-idUSKBN1ZT350
# 67 https://www.reuters.com/article/us-internet-regulation-justice/u-s-sets-meeting-on-liability-for-posts-on-facebook-other-platforms-idUSKBN1ZT31F
# 68 https://www.reuters.com/article/us-gymnastics-usa/usa-gymnastics-files-plan-to-emerge-from-bankruptcy-idUSKBN1ZT2YI
# 69 https://www.reuters.com/article/us-usa-farms-bankruptcy/u-s-farm-bankruptcies-hit-an-eight-year-high-court-data-idUSKBN1ZT2YE
# 70 https://www.reuters.com/article/us-china-health-usa/u-s-evacuees-from-china-placed-on-72-hour-hold-at-california-military-base-for-medical-evaluation-idUSKBN1ZT01D
# 71 https://www.reuters.com/article/us-bayer-glyphosate-epa/u-s-epa-reaffirms-that-glyphosate-does-not-cause-cancer-idUSKBN1ZT2SB
# 72 https://www.reuters.com/article/ip-google-philips/google-gets-another-philips-smartphone-patent-nixed-at-the-fed-circuit-idUSL1N29Z280
# 73 https://www.reuters.com/article/usa-environment-lawsuit/u-s-navy-green-groups-propose-settlement-of-ships-pollution-lawsuit-idUSL1N29Z283
# 74 https://www.reuters.com/article/employment-railroad/train-engineers-suspension-for-delay-in-reporting-fight-not-retaliation-8th-circuit-idUSL1N29Z282
# 75 https://www.reuters.com/article/us-usa-court-mobilephone/u-s-supreme-court-rejects-challenge-to-berkeley-cell-phone-law-idUSKBN1YD1K8
# 76 https://www.reuters.com/article/us-usa-court-transgender/u-s-supreme-court-rejects-inmates-bid-for-sex-reassignment-surgery-idUSKBN1YD1QP
# 77 https://www.reuters.com/article/us-usa-court-purduepharma-opioids/u-s-supreme-court-rejects-arizona-opioid-case-against-purdue-sackler-family-idUSKBN1YD1LE
# 78 https://www.reuters.com/article/us-usa-court-abortion/u-s-supreme-court-leaves-in-place-kentucky-abortion-restriction-idUSKBN1YD1JX
# 79 https://www.reuters.com/article/us-usa-court-deathpenalty/u-s-supreme-court-rejects-trump-bid-to-resume-federal-executions-idUSKBN1YA2ME
# 80 https://www.reuters.com/article/us-usa-court-trump-records/u-s-justice-ginsburg-puts-temporary-hold-on-trump-financial-records-dispute-idUSKBN1YA2BA
# 81 https://www.reuters.com/article/us-otc-facebook/does-facebooks-550-million-settlement-change-the-privacy-class-action-game-idUSKBN1ZT33O
# 82 https://www.reuters.com/article/us-otc-adr/foreign-issuers-beware-toshiba-didnt-sponsor-adrs-but-investor-class-action-gets-green-light-idUSKBN1ZS318
# 83 https://www.reuters.com/article/us-otc-fca/doj-eyes-requirement-that-false-claims-act-whistleblowers-disclose-litigation-funding-idUSKBN1ZR2VU
# 84 https://www.reuters.com/article/us-hitachi-m-a/hitachi-makes-5-billion-offer-for-full-control-of-industrial-gear-unit-idUSKBN1ZU0L3
# 85 https://www.reuters.com/article/us-japan-display-funding/apple-supplier-japan-display-gets-920-million-bailout-from-ichigo-idUSKBN1ZU0ZH
# 86 https://www.reuters.com/article/us-navistar-intl-m-a-traton-de-offer/volkswagen-truck-unit-traton-offers-2-9-billion-to-take-over-navistar-idUSKBN1ZT355
# 87 https://www.reuters.com/article/us-cocokara-fine-m-a-matsumotokysh-hd/japan-drugstore-matsumotokiyoshi-to-buy-20-of-rival-aims-for-full-merger-next-year-idUSKBN1ZU0E7
# 88 https://www.reuters.com/article/us-louisdreyfus-strategy-exclusive/exclusive-in-break-from-past-louis-dreyfus-boss-is-open-to-selling-stake-idUSKBN1ZT21D
# 89 https://www.reuters.com/article/us-renault-nissan/renault-nissan-can-overhaul-alliance-without-ownership-change-chairman-says-idUSKBN1ZT1AE
# 90 https://www.reuters.com/article/us-bco-daycoval-ipo-exclusive/exclusive-brazil-lender-banco-daycoval-plans-to-raise-close-to-1-billion-in-ipo-sources-idUSKBN1ZT32O
# 91 https://www.reuters.com/article/us-astonmartin-stroll-history-timeline/timeline-twists-and-turns-in-aston-martins-long-history-idUSKBN1ZU15W
# 92 https://www.reuters.com/article/us-volkswagen-m-a-renk/triton-offers-to-buy-renk-for-97-80-euros-a-share-idUSKBN1ZT38J
# 93 https://www.reuters.com/article/us-reynolds-cnsmr-ipo/reynolds-shakes-off-market-jitters-with-years-first-big-ipo-idUSKBN1ZT34G
# 94 https://www.reuters.com/article/us-navistar-intl-m-a-traton-de-share/vws-traton-offers-to-buy-rival-navistar-for-35-per-share-idUSKBN1ZT33A
# 95 https://www.reuters.com/article/us-navistar-intl-m-a-traton-de/german-truck-maker-traton-offers-to-buy-remaining-navistar-stake-for-2-9-billion-idUSKBN1ZT32D
# 96 https://www.reuters.com/article/us-libya-oil-eni-gas-e-luce/joint-venture-between-libyas-national-oil-corp-and-italys-eni-losing-155000-bpd-of-oil-due-to-blockade-noc-idUSKBN1ZT342
# 97 https://www.reuters.com/article/us-brazil-nuclear/brazils-eletronuclear-to-sign-letter-of-intent-with-westinghouse-idUSKBN1ZT2MX
# 98 https://www.reuters.com/article/us-enterprise-prodt-results/enterprise-products-expects-to-complete-part-of-wink-to-webster-crude-pipeline-by-year-end-idUSKBN1ZT2LR
# 99 https://www.reuters.com/article/us-continent-volkswagen/continentals-vitesco-gets-contract-from-volkswagen-handelsblatt-idUSKBN1ZT2KY
# 100 https://www.reuters.com/article/us-vodafone-telecom-it-towers-iliad/iliad-raises-antitrust-concerns-over-tim-vodafone-tower-deal-idUSKBN1ZT2CK
# 101 https://www.reuters.com/article/us-honeywell-intl-results/honeywell-says-737-max-grounding-to-hurt-sales-growth-in-2020-idUSKBN1ZU1M1
# 102 https://www.reuters.com/article/us-senior-boeing/senior-warns-of-20-aerospace-revenue-fall-from-737-max-grounding-idUSKBN1ZU0SJ
# 103 https://www.reuters.com/article/us-syria-security-kremlin/kremlin-russia-deeply-concerned-by-attacks-on-syria-government-forces-idUSKBN1ZU149
# 104 https://www.reuters.com/article/us-china-health-iran/iran-health-minister-urges-government-to-ban-entry-of-travelers-from-china-idUSKBN1ZU12E
# 105 https://www.reuters.com/article/us-china-health-uk-passengers/plane-leaves-china-virus-epicenter-with-110-britons-and-foreigners-aboard-idUSKBN1ZU0FN
# 106 https://www.reuters.com/article/us-china-health-oman/oman-advises-against-travel-to-china-due-to-coronavirus-outbreak-idUSKBN1ZU0ZF
# 107 https://www.reuters.com/article/us-china-health-pakistan/pakistan-halts-flights-to-and-from-china-civil-aviation-authority-idUSKBN1ZU0G1
# 108 https://www.reuters.com/article/us-usa-airplanes-emissions/u-s-environmental-groups-plan-to-sue-trump-administration-on-airplane-emissions-idUSKBN1ZT2LV
# 109 https://www.reuters.com/article/us-china-health-singapore-air/singapore-airlines-to-reduce-capacity-to-mainland-china-in-february-due-to-virus-idUSKBN1ZT37D
# 110 https://www.reuters.com/article/us-embraer-skywest/skywest-adds-20-first-gen-embraer-jets-as-order-for-new-version-remains-on-hold-idUSKBN1ZT30M
# 111 https://www.reuters.com/article/us-deutsche-bank-results/turnaround-costs-push-deutsche-bank-to-6-billion-loss-idUSKBN1ZT0GH
# 112 https://www.reuters.com/article/us-fx-survey-jp-morgan/trading-liquidity-tops-fx-markets-concerns-in-2020-survey-idUSKBN1ZT008
# 113 https://www.reuters.com/article/us-goldman-sachs-investor-day/goldman-sachs-sets-growth-targets-but-urges-investor-patience-idUSKBN1ZS0ID
# 114 https://www.reuters.com/article/us-akeso-ipo/u-s-banks-on-hong-kong-exchanges-named-and-shamed-list-idUSKBN1ZS22T
# 115 https://www.reuters.com/article/us-china-health-economy-morgan-stanley/morgan-stanley-warns-coronavirus-could-drag-on-global-chinese-gdp-growth-idUSKBN1ZS27P
# 116 https://www.reuters.com/article/us-hsbc-turkey-exclusive/exclusive-hsbc-considering-exit-from-turkey-sources-idUSKBN1ZS1R2
# 117 https://www.reuters.com/article/us-deutsche-bank-pay/deutsche-bank-delays-raises-to-fixed-pay-after-changing-annual-date-for-pay-adjustments-idUSKBN1ZR2PZ
# 118 https://www.reuters.com/article/us-credit-suisse-spying-exclusive/exclusive-regulator-probes-board-role-in-credit-suisse-spying-scandal-sources-idUSKBN1ZQ014
# 119 https://www.reuters.com/article/us-wells-fargo-probes-factbox/remaining-hurdles-for-scandal-hit-wells-fargo-idUSKBN1ZN2AL
# 120 https://www.reuters.com/article/us-precious-rhodium/rhodium-prices-hit-record-high-after-spectacular-rally-idUSKBN1ZU184
# 121 https://www.reuters.com/article/us-china-health-autos/china-auto-sector-braces-for-hefty-virus-impact-hopes-it-will-be-short-lived-idUSKBN1ZU0GG
# 122 https://www.reuters.com/article/us-china-health-ssangyong-motor/hyundai-motor-to-suspend-some-suv-output-in-south-korea-as-virus-disrupts-supplies-idUSKBN1ZU0Y7
# 123 https://www.reuters.com/article/us-china-health-trade/china-trade-agency-to-offer-firms-force-majeure-certificates-amid-coronavirus-outbreak-idUSKBN1ZU075
# 124 https://www.reuters.com/article/us-mitsubishimotors-results/mitsubishi-motors-posts-surprise-third-quarter-operating-loss-as-car-sales-slide-idUSKBN1ZU0PV
# 125 https://www.reuters.com/article/us-tesla-solarcity-lawsuit/tesla-directors-settle-isolating-musk-as-solarcity-trial-looms-idUSKBN1ZT2HF
# 126 https://www.reuters.com/article/us-usa-trade-cbp/u-s-collected-nearly-73-more-duties-in-fiscal-2019-as-trade-wars-raged-idUSKBN1ZU015
# 127 https://www.reuters.com/article/us-levi-strauss-results/levis-shuts-half-its-china-stores-on-coronavirus-outbreak-expects-financial-hit-idUSKBN1ZT2ZL
# 128 https://www.reuters.com/article/us-aston-martin-funding/aston-martin-calls-board-meeting-to-decide-on-fundraising-idUSKBN1ZT2HM
# 129 https://www.reuters.com/article/us-usa-economy-jobs-trump-analysis/companies-trump-said-would-create-thousands-of-jobs-have-failed-to-deliver-idUSKBN1ZT18L
# 130 https://www.reuters.com/article/us-aptiv-results-ceo/aptiv-ceo-sees-growth-as-auto-production-falls-but-shares-drop-idUSKBN1ZT2EE
# 131 https://www.reuters.com/article/us-meritor-brazil/u-s-autoparts-maker-meritor-to-invest-48-million-in-third-brazil-plant-idUSKBN1ZT2E6
# 132 https://www.reuters.com/article/china-health-southkorea/update-4-south-korean-evacuees-from-wuhan-welcomed-to-quarantine-centres-idUSL4N2A0074
# 133 https://www.reuters.com/article/china-health-oil/refile-air-travel-fears-due-to-coronavirus-to-sap-oil-demand-idUSL8N2A02Q0
# 134 https://www.reuters.com/article/china-health/wrapup-9-u-s-and-others-tighten-curbs-on-travel-to-china-virus-toll-hits-213-idUSL4N29Z6DC
# 135 https://www.reuters.com/article/greece-privatisation-airport/greece-shortlists-9-investors-for-30-stake-in-athens-airport-idUSA8N28L066
# 136 https://www.reuters.com/article/us-investment-summit-protests/investors-wary-as-social-unrest-spreads-from-hong-kong-to-santiago-idUSKBN1XL0J6
# 137 https://www.reuters.com/article/us-shipping-environment-finance/credit-suisse-others-back-initiative-to-factor-co2-cuts-into-shipping-finance-idUSKBN1ZT2GU
# 138 https://www.reuters.com/article/us-australia-gas/australia-aims-to-boost-east-coast-gas-supply-clean-energy-in-1-4-billion-deal-idUSKBN1ZU08G
# 139 https://www.reuters.com/article/us-climate-change-airlines/global-airline-group-to-launch-carbon-exchange-platform-to-address-climate-change-idUSKBN1ZT1VY
# 140 https://www.reuters.com/article/us-usa-illinois-pjm-nuclearpower/illinois-governor-wants-clean-energy-legislation-could-push-state-out-of-pjm-power-grid-idUSKBN1ZT259
# 141 https://www.reuters.com/article/us-global-markets-breakingviews/breakingviews-cox-consensus-long-on-trump-short-on-facebook-idUSKBN1ZU1C6
# 142 https://www.reuters.com/article/us-icehockey-women-feature/as-wnba-boosts-pay-womens-hockey-players-see-path-forward-idUSKBN1ZL2L8
# 143 https://www.reuters.com/article/us-usa-election-bloomberg/bloomberg-makes-pitch-to-women-says-he-regrets-bawdy-jokes-idUSKBN1ZE2N3
# 144 https://www.reuters.com/article/us-motor-wseries/formula-one-link-up-boosts-all-female-w-series-idUSKBN1ZF1TV
# 145 https://www.reuters.com/article/us-tech-nso-amnesty/israeli-surveillance-software-lawsuit-goes-behind-closed-doors-idUSKBN1ZF1AI
# 146 https://www.reuters.com/article/us-usa-saudi-shooting-mnuchin/mnuchin-urges-apple-other-tech-companies-to-work-with-law-enforcement-idUSKBN1ZE1Q7
# 147 https://www.reuters.com/article/us-usa-saudi-shooting-trump/trump-criticizes-apples-encryption-stance-on-pensacola-phones-idUSKBN1ZD2WF
# 148 https://www.reuters.com/article/us-eu-eib/eib-to-borrow-some-50-billion-euros-in-2020-invest-one-third-in-green-projects-idUSKBN1ZT25N
# 149 https://www.reuters.com/article/us-eurozone-eurogroup-gentiloni/eu-to-add-vetting-of-climate-results-to-fiscal-monitoring-idUSKBN1ZJ1VB
# 150 https://www.reuters.com/article/us-climatechange-cenbank-bis/central-banks-cant-save-the-world-from-climate-change-bis-says-idUSKBN1ZJ19E
# 151 https://www.reuters.com/article/us-climatechange-church-of-england-pensi/church-of-england-pension-fund-shifts-789-million-to-climate-index-idUSKBN1ZT1DE
# 152 https://www.reuters.com/article/us-usa-fed-climatechange/fed-has-a-role-in-combating-climate-change-risk-powell-says-idUSKBN1ZT031
# 153 https://www.reuters.com/article/us-uniper-coal-exclusive/uniper-to-shut-down-german-hard-coal-power-plants-by-2025-idUSKBN1ZT10H
# 154 https://www.reuters.com/article/us-india-pollution-coal/indias-pollution-regulator-ponders-coal-plant-penalties-idUSKBN1ZS2B2
# 155 https://www.reuters.com/article/us-world-work-vrtraining/to-train-more-workers-companies-turn-to-virtual-reality-idUSKBN1ZL1AN
# 156 https://www.reuters.com/article/us-southkorea-artificial-intelligence-jo/smile-with-your-eyes-how-to-beat-south-koreas-ai-hiring-bots-and-land-a-job-idUSKBN1ZC022
# 157 https://www.reuters.com/article/us-world-work-softskills/how-can-generation-z-compete-with-robots-focus-on-the-human-touch-idUSKBN1YK0CM
# 158 https://www.reuters.com/article/us-japan-harassment-appearance/specs-on-heels-off-japanese-activists-urge-changes-to-anti-harassment-code-idUSKBN1Y70QT
# 159 https://www.reuters.com/article/us-world-work-givingtuesday/your-money-on-givingtuesday-companies-turbocharge-holiday-giving-efforts-idUSKBN1Y12F1
# 160 https://www.reuters.com/article/us-world-work-vetrepreneurs/helping-veterans-develop-business-skills-as-entrepreneurs-idUSKBN1XL2LS
# 161 https://www.reuters.com/article/us-world-work-mentalhealth/culture-change-is-the-cutting-edge-of-mental-health-benefits-at-work-idUSKBN1XI196
# 162 https://www.reuters.com/article/us-woolworths-grp-results/woolworths-underpaid-staff-by-up-to-200-million-fuels-ire-over-australian-wage-scandals-idUSKBN1X82N3
# 163 https://www.reuters.com/article/us-southkorea-safety-insight/in-south-koreas-dangerous-shipyards-subcontracted-workers-are-most-at-risk-idUSKBN1X82QS
# 164 https://www.reuters.com/article/us-world-work-schawbel/despite-robot-efficiency-human-skills-still-matter-at-work-idUSKBN1X41CK
# 165 https://www.reuters.com/article/us-world-work-benefits/workers-in-pain-employers-take-a-new-twist-to-prevent-costly-injuries-idUSKBN1X21DK
# 166 https://www.reuters.com/article/us-china-health-investors/virus-fears-turn-big-investors-bearish-on-asian-currencies-for-now-idUSKBN1ZU1DF
# 167 https://www.reuters.com/article/global-forex/forex-trade-linked-currencies-fall-on-worries-about-fallout-from-virus-idUSL8N2A03H0
# 168 https://www.reuters.com/article/britain-eu-leaders/update-2-eu-seeks-to-put-brave-face-on-brexit-day-warns-uk-of-costs-of-divergence-idUSL8N2A02HF
# 169 https://www.reuters.com/article/lebanon-crisis-banks/lebanon-finmin-asks-banking-association-to-reduce-interest-rates-statement-idUSS8N27C00Y
# 170 https://www.reuters.com/article/europe-stocks/update-2-european-shares-drop-on-coronavirus-cases-weak-euro-zone-data-idUSL4N2A03DI
# 171 https://www.reuters.com/article/eurozone-bonds-orders/euro-zone-sovereigns-enjoy-record-demand-at-january-bond-sales-idUSL8N29W531
# 172 https://www.reuters.com/article/press-digest-canada/press-digest-canada-jan-31-idUSL4N2A0449
# 173 https://www.reuters.com/article/parana-banco-ipo/brazilian-lender-parana-banco-considers-ipo-filing-idUSL1N2A0096
# 174 https://www.reuters.com/article/kkr-results/kkrs-fourth-quarter-profit-drops-by-nearly-a-fifth-idUSL1N29X12W
# 175 https://www.reuters.com/article/climatechange-investors-proxy/top-u-s-fund-firms-split-over-new-limits-on-shareholder-votes-idUSL1N29Z222
# 176 https://www.reuters.com/article/eurozone-bonds/rpt-update-1-euro-zone-bonds-brush-off-data-releases-idUSL8N2A03WE
# 177 https://www.reuters.com/article/us-europe-stocks/bank-stocks-help-european-shares-climb-on-brexit-day-idUSKBN1ZU0WR
# 178 https://www.reuters.com/article/europe-stocks/european-shares-climb-in-early-trading-on-brexit-day-idUSL4N2A0365
# 179 https://www.reuters.com/article/europe-stocks/update-2-weak-earnings-hit-europe-amid-virus-fears-ftse-slides-as-boe-stands-pat-idUSL4N29Z2P6
# 180 https://www.reuters.com/article/us-europe-stocks/european-shares-slide-on-weak-earnings-china-virus-epidemic-idUSKBN1ZT0TN
# 181 https://www.reuters.com/article/europe-stocks/european-shares-skid-as-china-epidemic-fuels-economic-worry-idUSL4N29Z2LF
# 182 https://www.reuters.com/article/us-europe-stocks/santander-buoys-european-shares-but-coronavirus-fears-persist-idUSKBN1ZS0Y2
# 183 https://www.reuters.com/article/europe-stocks/update-2-santander-buoys-european-shares-but-coronavirus-fears-persist-idUSL4N29Y1Z2
# 184 https://www.reuters.com/article/europe-stocks/bank-stocks-lift-european-shares-idUSL4N29Y1W6
# 185 https://www.reuters.com/article/europe-stocks-coronavirus/rpt-graphic-why-the-devil-coronavirus-has-hit-european-stocks-hard-idUSL8N29X5UI
# 186 https://www.reuters.com/article/us-europe-stocks-results/europe-inc-expected-fourth-quarter-profit-growth-continues-to-shrink-idUSKBN1ZS0KA
# 187 https://www.reuters.com/article/china-health-britain-nhs/uk-well-prepared-to-deal-with-virus-pm-johnsons-spokesman-idUSL9N28503F
# 188 https://www.reuters.com/article/global-markets/global-markets-shares-struggle-for-footing-after-virus-battered-week-idUSL8N2A02BP
# 189 https://www.reuters.com/article/global-forex/forex-chinas-yuan-finds-its-feet-on-who-confidence-aussie-extends-slide-idUSL8N2A01V0
# 190 https://www.reuters.com/article/emerging-markets/emerging-markets-em-stocks-log-dour-week-as-china-epidemic-dents-growth-optimism-idUSL8N2A026F
# 191 https://www.reuters.com/article/japan-stocks-close/nikkei-ends-higher-but-sees-worst-week-in-6-months-as-virus-spreads-idUSL4N2A02OO
# 192 https://www.reuters.com/article/global-markets/global-markets-asia-shares-struggle-for-footing-after-rough-virus-scarred-week-idUSL4N2A02PZ
# 193 https://www.reuters.com/article/global-forex/forex-battered-asian-currencies-arrest-slide-on-who-confidence-idUSL4N2A023H
# 194 https://www.reuters.com/article/global-markets/global-markets-asia-shares-struggle-for-footing-after-fraught-week-idUSL4N2A01FD
# 195 https://www.reuters.com/article/japan-stocks-midday/nikkei-bounces-back-on-earnings-to-cap-week-hit-by-epidemic-fears-idUSL4N2A018W
# 196 https://www.reuters.com/article/global-markets/global-markets-asia-shares-fight-for-footing-after-turbulent-week-idUSL4N2A00MR
# 197 https://www.reuters.com/article/brazil-economy-employment/update-1-brazils-jobless-rate-drops-to-11-0-lowest-in-almost-four-years-idUSL1N2A00AB
# 198 https://www.reuters.com/article/europe-stocks/update-2-european-shares-recover-from-viral-outbreak-fuelled-sell-off-idUSL4N29X1JR
# 199 https://www.reuters.com/article/europe-stocks/european-shares-rebound-from-worst-day-in-nearly-four-months-idUSL4N29X1FY
# 200 https://www.reuters.com/article/europe-stocks/update-3-coronavirus-fears-wipe-billions-from-european-stocks-idUSL4N29W10V
# 201 https://www.reuters.com/article/europe-stocks/european-shares-slump-as-coronavirus-fears-worsen-idUSL4N29W0ZV
# 202 https://www.reuters.com/article/britain-stocks-factors/update-1-uk-stocks-factors-to-watch-on-jan-31-idUSL4N2A02ZH
# 203 https://www.reuters.com/article/britain-stocks-factors/uk-stocks-factors-to-watch-on-jan-28-idUSL4N29X0WF
# 204 https://www.reuters.com/article/brief-roche-receives-positive-chmp-opini/brief-roche-receives-positive-chmp-opinion-for-lymphocytic-leukaemia-drug-idUSFWN2A00LK
# 205 https://www.reuters.com/article/britain-eu-markets/update-2-eu-checks-uk-compliance-with-market-rules-after-brexit-idUSL8N2A02FC
# 206 https://www.reuters.com/article/china-health-india-manufacturing/update-1-china-virus-causes-scare-for-indias-smartphone-makers-idUSL8N2A037M
# 207 https://www.reuters.com/article/hkex-wvr/update-1-hong-kong-exchange-proposes-allowing-corporate-weighted-voting-rights-idUSL4N2A03JZ
# 208 https://www.reuters.com/article/china-health-investors/virus-fears-turn-big-investors-bearish-on-asian-currencies-for-now-idUSL4N2A03I7
# 209 https://www.reuters.com/article/india-stocks/indian-shares-end-lower-ahead-of-budget-energy-stocks-lead-losses-idUSL4N2A03U1
# 210 https://www.reuters.com/article/southeast-asia-stocks/se-asia-stocks-post-heavy-losses-as-virus-toll-passes-200-rattles-sentiment-idUSL4N2A03GS
# 211 https://www.reuters.com/article/cocokara-fine-ma-matsumotokysh-hd/update-3-japan-drugstore-matsumotokiyoshi-to-buy-20-of-rival-aims-for-full-merger-next-year-idUSL4N2A01T5
# 212 https://www.reuters.com/article/china-stocks-hongkong-close/hong-kong-shares-fall-to-near-two-month-low-on-coronavirus-fears-idUSAZN18LS00
# 213 https://www.reuters.com/article/astellas-pharma-results/update-2-astellas-pharma-keeps-profit-forecast-as-prostate-cancer-drug-sales-rise-idUSL4N2A01HH
# 214 https://www.reuters.com/article/china-health-taiwan-markets/update-2-taiwan-finmin-says-now-not-the-time-to-intervene-in-markets-idUSL4N2A00V3
# 215 https://www.reuters.com/article/india-markets-funds/rpt-graphic-indian-investors-eschew-equity-funds-as-economy-falters-idUSL4N2A02N4
# 216 https://www.reuters.com/article/australia-stocks-close/australia-nz-shares-helped-by-china-pmi-virus-anxiety-caps-gains-idUSL4N2A0287
# 217 https://www.reuters.com/article/india-markets-funds/graphic-indian-investors-eschew-equity-funds-as-economy-falters-idUSL4N29X1F7
# 218 https://www.reuters.com/article/china-stocks-hongkong-midday/hong-kong-shares-find-footing-as-investors-hunt-for-bargains-idUSL4N2A01TC
# 219 https://www.reuters.com/article/southeast-asia-stocks/se-asia-stocks-extend-losses-as-coronavirus-fears-deepen-philippines-falls-most-idUSL4N2A01KO
# 220 https://www.reuters.com/article/india-stocks/indian-shares-rise-as-banks-gain-all-eyes-on-budget-idUSL4N2A01RW
# 221 https://www.reuters.com/article/eurozone-bonds/update-1-euro-zone-bonds-brush-off-data-releases-idUSL8N2A02UP
# 222 https://www.reuters.com/article/us-britain-eu-trade/uk-government-wants-canada-style-free-trade-deal-with-eu-spokesman-for-pm-johnson-idUSKBN1ZU1HS
# 223 https://www.reuters.com/article/us-eurozone-economy/euro-zone-growth-below-expectations-core-inflation-slows-idUSKBN1ZU14V
# 224 https://www.reuters.com/article/uk-britain-eu-ireland/irish-pm-says-eu-britain-not-that-far-away-on-trade-idUSKBN1ZU1A5
# 225 https://www.reuters.com/article/china-health-italy/italy-govt-agrees-state-of-emergency-after-confirmed-coronavirus-cases-govt-source-idUSR1N282044
# 226 https://www.reuters.com/article/astonmartin-stroll-history/timeline-twists-and-turns-in-aston-martins-long-history-idUSL4N29D3OD
# 227 https://www.reuters.com/article/eurozone-economy/euro-zone-gdp-falls-short-of-expectations-inflation-picks-up-idUSL8N2A02QO
# 228 https://www.reuters.com/article/britain-eu-ireland/irish-pm-says-eu-britain-not-that-far-away-on-trade-deal-idUSL8N2A02O7
# 229 https://www.reuters.com/article/eurozone-bonds/euro-zone-bonds-steady-investors-await-inflation-and-gdp-data-idUSL8N2A01X3
# 230 https://www.reuters.com/article/japan-bonds/jgbs-mostly-firm-on-coronavirus-fears-curve-steepens-idUSL4N2A02VE
# 231 https://www.reuters.com/article/australia-banks-mortgages/australias-cba-big-offshore-banks-grow-home-lending-business-idUSL4N2A025Q
# 232 https://www.reuters.com/article/mexico-budget/update-1-mexicos-primary-budget-surplus-for-2019-higher-than-envisioned-idUSL1N2A0039
# 233 https://www.reuters.com/article/mexico-budget/mexico-reports-primary-budget-surplus-of-1-1-for-2019-idUSL1N2A0030
# 234 https://www.reuters.com/article/uk-global-forex/safe-haven-demand-cools-as-virus-fears-wane-dollar-still-bid-idUSKBN1ZR02Y
# 235 https://www.reuters.com/article/uk-britain-sterling/sterling-drops-on-brexit-trade-deal-concerns-boe-nerves-idUSKBN1ZR0UX
# 236 https://www.reuters.com/article/uk-britain-sterling/sterling-extends-gains-after-boe-keeps-rates-on-hold-idUSKBN1ZU15S
# 237 https://www.reuters.com/article/uk-mexico-peso/the-paradox-of-the-peso-mexican-currency-benefits-from-weak-economy-idUSKBN1ZQ2FK
# 238 https://www.reuters.com/article/us-global-forex/safe-havens-up-aussie-yuan-weaken-as-coronavirus-toll-rises-idUSKBN1ZP0V9
# 239 https://www.reuters.com/article/uk-britain-sterling/sterling-dips-ahead-of-central-bank-rate-decision-long-bets-trimmed-idUSKBN1ZQ0QY
# 240 https://www.reuters.com/article/us-global-forex/dollar-dips-vs-yen-as-investors-reach-for-safe-havens-on-virus-scare-idUSKBN1ZN03B
# 241 https://www.reuters.com/article/uk-britain-sterling/pound-drops-as-rate-cut-remains-possible-despite-better-data-idUSKBN1ZN0SA
# 242 https://www.reuters.com/article/us-global-forex/dollar-up-vs-euro-as-ecb-holds-rates-steady-launches-review-idUSKBN1ZM08K
# 243 https://www.reuters.com/article/uk-britain-sterling/pound-extends-gains-as-rate-cut-bets-melt-idUSKBN1ZM13H
# 244 https://www.reuters.com/article/uk-global-forex/dollar-steady-as-coronavirus-contagion-fears-abate-idUSKBN1ZL01N
# 245 https://www.reuters.com/article/uk-britain-sterling/sterling-gains-further-as-boe-rate-cut-fears-recede-idUSKBN1ZL0WD
# 246 https://www.reuters.com/article/uk-usa-markets-dollar-analysis/death-cross-growth-abroad-threaten-u-s-dollar-idUSKBN1ZL0IN
# 247 https://www.reuters.com/article/uk-global-forex/yuan-weakens-safe-havens-gain-on-chinese-virus-concerns-idUSKBN1ZK022
# 248 https://www.reuters.com/article/uk-britain-sterling/sterling-rallies-after-uk-jobs-growth-weakens-case-for-rate-cut-idUSKBN1ZK0T1
# 249 https://www.reuters.com/article/uk-britain-sterling/sterling-falls-after-javid-comments-stoke-hard-brexit-fears-idUSKBN1ZJ0WZ
# 250 https://www.reuters.com/article/us-global-forex/dollar-gains-as-u-s-economic-strength-supports-sentiment-idUSKBN1ZJ037
# 251 https://www.reuters.com/article/uk-cftc-forex/speculators-cut-long-dollar-bets-to-19-month-low-cftc-reuters-idUSKBN1ZG2DX
# 252 https://www.reuters.com/article/us-global-forex/dollar-gains-on-u-s-economic-optimism-idUSKBN1ZG045
# 253 https://www.reuters.com/article/uk-britain-sterling/pound-reverses-gains-after-bleak-british-retail-sales-idUSKBN1ZG0X2
# 254 https://www.reuters.com/article/uk-global-forex/dollar-gains-on-positive-u-s-economic-data-idUSKBN1ZF04K
# 255 https://www.reuters.com/article/uk-britain-sterling/sterling-rises-to-one-week-high-as-traders-await-data-cues-on-boe-rate-decision-idUSKBN1ZF1FC
# 256 https://www.reuters.com/article/us-global-forex/dollar-weakens-as-u-s-china-sign-trade-deal-idUSKBN1ZE03O
# 257 https://www.reuters.com/article/us-canada-pipeline/prospects-advance-for-canadas-oil-pipelines-but-hurdles-remain-idUSKBN1ZU1K5
# 258 https://www.reuters.com/article/us-china-economy-trade-oil/china-oil-imports-from-top-supplier-saudi-arabia-rise-47-in-2019-customs-idUSKBN1ZU0EH
# 259 https://www.reuters.com/article/us-canada-pipeline-factbox/factbox-canadas-oil-pipeline-projects-inch-forward-idUSKBN1ZU1KW
# 260 https://www.reuters.com/article/us-nigeria-oil/nigerian-court-issues-warrant-for-oil-minister-etetes-in-1-3-billion-oil-deal-idUSKBN1ZT1UT
# 261 https://www.reuters.com/article/us-papua-exxon-mobil/png-says-fails-to-agree-with-exxon-mobil-on-pnyang-gas-project-idUSKBN1ZU1AQ
# 262 https://www.reuters.com/article/us-nippon-steel-shutdown/japans-nippon-steel-to-cut-10-of-crude-steel-capacity-nikkei-idUSKBN1ZU06U
# 263 https://www.reuters.com/article/us-iran-nuclear-usa-cosco/u-s-to-lift-iran-related-sanctions-on-units-of-chinese-shipper-cosco-sources-idUSKBN1ZU04I
# 264 https://www.reuters.com/article/us-s-oil-results/s-oil-sees-refining-margins-improving-on-imo-2020-easing-trade-tensions-idUSKBN1ZU034
# 265 https://www.reuters.com/article/us-chesapeake-enrgy-blowout-probe/authorities-probe-fatal-blast-at-chesapeake-energy-drill-site-in-texas-idUSKBN1ZT29C
# 266 https://www.reuters.com/article/us-jbs-brf-antitrust/brazil-antitrust-regulator-opens-probe-into-meatpackers-jbs-and-brf-idUSKBN1ZT313
# 267 https://www.reuters.com/article/us-corteva-soybeans-seeds/corteva-speeds-up-north-america-biotech-soy-seed-rollout-challenging-bayer-idUSKBN1ZT2CY
# 268 https://www.reuters.com/article/us-usa-stocks-energy/december-bump-in-oil-prices-not-enough-to-salvage-energy-earnings-idUSKBN1ZT2XC
# 269 https://www.reuters.com/article/us-global-oil/oil-falls-to-new-three-month-lows-as-virus-fears-grow-opec-mulls-meeting-idUSKBN1ZT05V
# 270 https://www.reuters.com/article/us-usa-penneast-new-jersey/u-s-ferc-sides-with-penneast-natgas-pipeline-new-jersey-eminent-domain-case-idUSKBN1ZT2VH
# 271 https://www.reuters.com/article/us-usa-refineries-insurance/u-s-refiners-chemical-makers-pare-insurance-coverage-as-accidents-boost-costs-idUSKBN1ZT0FB
# 272 https://www.reuters.com/article/us-ecopetrol-colombia/colombias-ecopetrol-commits-to-stop-routine-gas-flaring-at-operations-idUSKBN1ZT2PP
# 273 https://www.reuters.com/article/us-global-lng-china-u-s/u-s-lng-producers-fear-more-price-drops-as-they-await-china-buys-under-phase-1-deal-idUSKBN1ZT2N8
# 274 https://www.reuters.com/article/us-cenovus-indigenous/canadas-cenovus-energy-to-build-houses-for-indigenous-communities-idUSKBN1ZT2L2
# 275 https://www.reuters.com/article/us-enbridge-inc-pipeline-oil/enbridge-defends-plan-to-sell-capacity-on-mainline-oil-network-idUSKBN1ZT2M9
# 276 https://www.reuters.com/article/us-china-health-economy-goldman/goldman-sachs-says-virus-outbreak-to-hit-u-s-and-china-growth-idUSKBN1ZU0QP
# 277 https://www.reuters.com/article/us-india-markets-funds/indian-investors-eschew-equity-funds-as-economy-falters-idUSKBN1ZU0J0
# 278 https://www.reuters.com/article/us-usa-sec-roisman-proxy/u-s-sec-commissioner-defends-proposal-on-shareholder-voting-rules-idUSKBN1ZU00Z
# 279 https://www.reuters.com/article/us-exxon-mobil-results/exxon-quarterly-profit-falls-5-2-on-weak-refining-chemical-margins-idUSKBN1ZU1OI
# 280 https://www.reuters.com/article/us-kkr-results/kkrs-fourth-quarter-profit-drops-by-nearly-a-fifth-idUSKBN1ZU1KU
# 281 https://www.reuters.com/article/us-caterpillar-results/caterpillar-sees-2020-profit-below-expectations-idUSKBN1ZU1IP
# 282 https://www.reuters.com/article/us-phillips-66-results/refiner-phillips-66-misses-profit-estimates-on-higher-shutdowns-idUSKBN1ZU1KY
# 283 https://www.reuters.com/article/us-electrolux-results/electrolux-shares-slump-after-warning-of-coronavirus-impact-idUSKBN1ZU0XJ
# 284 https://www.reuters.com/article/us-visa-results/visa-sees-muted-revenue-growth-in-2020-shares-fall-3-idUSKBN1ZT2Z3
# 285 https://www.reuters.com/article/us-citgo-dividends-exclusive/exclusive-as-citgo-profit-rises-pressure-to-restore-dividend-grows-sources-idUSKBN1Y82SQ
# 286 https://www.reuters.com/article/us-money-etf-dividend/starved-for-income-hungry-investors-hunt-dividend-etfs-idUSKBN1XB455
# 287 https://www.reuters.com/article/money-etf-dividend/starved-for-income-hungry-investors-hunt-dividend-etfs-idUSL2N27H029
# 288 https://www.reuters.com/article/us-japan-stocks-futures/foreigners-swap-bets-on-japans-stock-index-for-select-shares-idUSKBN1ZN0KY
# 289 https://www.reuters.com/article/us-japan-economy-boj-etf/boj-appeased-disgruntled-investors-in-etf-loan-scheme-sources-idUSKBN1ZN0JK
# 290 https://www.reuters.com/article/us-japan-economy-boj/boj-raises-growth-forecast-signals-status-quo-on-policy-outlook-idUSKBN1ZJ287
# 291 https://www.reuters.com/article/us-palladium-price-graphic/theres-no-metal-record-breaking-palladium-races-higher-idUSKBN1ZG1T6
# 292 https://www.reuters.com/article/us-blackrock-results/blackrock-profit-beats-estimates-as-assets-top-7-trillion-idUSKBN1ZE1E4
# 293 https://www.reuters.com/article/us-blackrock-results-fink/blackrock-ceo-fink-investors-not-overzealous-on-equities-despite-rally-idUSKBN1ZE1W9
# 294 https://www.reuters.com/article/us-china-market-fund/chinas-mutual-fund-industry-had-a-record-year-of-product-launches-shanghai-sec-news-idUSKBN1YZ01H
# 295 https://www.reuters.com/article/us-global-markets-decade-volatility/the-decade-that-saw-volatility-trading-come-of-age-idUSKBN1YY09E
# 296 https://www.reuters.com/article/us-global-markets-decade-funds/how-risky-etfs-won-the-decade-and-why-they-might-not-repeat-that-performance-idUSKBN1YS0BY
# 297 https://www.reuters.com/article/us-global-markets-decade-emerging/dismal-decade-for-emerging-markets-casts-pall-over-repeated-buy-notes-idUSKBN1YO0M2
# 298 https://www.reuters.com/article/us-money-retirement-debt/seniors-deal-with-the-harsh-reality-of-debt-idUSKBN1ZS2DK
# 299 https://www.reuters.com/article/us-climate-change-investors/new-york-state-pension-fund-puts-27-coal-companies-under-review-idUSKBN1ZS1GL
# 300 https://www.reuters.com/article/us-lipper-awards-stocks/u-s-lipper-award-winners-bet-big-on-brexit-global-slowdown-idUSKCN1QP0FD
# 301 https://www.reuters.com/article/us-china-health-hongkong/hong-kong-leader-rejects-calls-to-close-border-despite-virus-fears-idUSKBN1ZU1K6
# 302 https://www.reuters.com/article/us-australia-bushfires/australia-on-standby-for-fire-threat-as-heat-winds-return-idUSKBN1ZT36S
# 303 https://www.reuters.com/article/us-israel-palestinians-violence-un/u-n-aid-agency-fears-u-s-middle-east-plan-will-spark-violence-idUSKBN1ZU1MG
# 304 https://www.reuters.com/article/us-syria-security-turkey/erdogan-says-turkey-may-launch-syria-offensive-if-idlib-attacks-continue-idUSKBN1ZU11U
# 305 https://www.reuters.com/article/us-hungary-orban-prisons/hungary-to-build-more-prisons-to-tackle-overcrowding-halt-inmates-lawsuits-idUSKBN1ZU1JD
# 306 https://www.reuters.com/article/us-france-environment-landrights/french-couple-living-off-grid-wants-to-leave-a-trace-idUSKBN1ZU1BO
# 307 https://www.reuters.com/article/us-china-health-britain-cases/britain-reports-first-two-cases-of-new-coronavirus-idUSKBN1ZU12K
# 308 https://www.reuters.com/article/us-china-health-beijing/companies-in-beijing-to-resume-work-on-february-10-due-to-virus-fight-government-newspaper-idUSKBN1ZU1MW
# 309 https://www.reuters.com/article/us-china-health-myanmar/myanmar-turns-back-china-southern-flight-over-coronavirus-fears-government-spokesman-idUSKBN1ZU1KN
# 310 https://www.reuters.com/article/us-china-health-siemens-health/siemens-healthineers-supplies-diagnostic-equipment-to-wuhan-hospitals-idUSKBN1ZU1JN
# 311 https://www.reuters.com/article/us-senegal-women-activist/in-senegal-online-videos-break-silence-over-domestic-abuse-idUSKBN1ZU11W
# 312 https://www.reuters.com/article/us-china-health-usa-travel/u-s-state-department-warns-americans-against-china-travel-over-virus-idUSKBN1ZU07H
# 313 https://www.reuters.com/article/us-nfl-football-superbowl/players-say-safety-key-in-debate-over-17-game-regular-season-idUSKBN1ZU0CU
# 314 https://www.reuters.com/article/us-china-health-usa/u-s-confirms-its-first-person-to-person-coronavirus-transmission-idUSKBN1ZT2N2
# 315 https://www.reuters.com/article/us-usa-immigration-brazil/brazilians-sent-to-mexico-by-u-s-say-they-dont-understand-why-idUSKBN1ZU0AO
# 316 https://www.reuters.com/article/us-usa-trump-impeachment-senators-factbo/republican-senators-to-watch-in-battle-over-trump-impeachment-trial-witnesses-idUSKBN1ZT211
# 317 https://www.reuters.com/article/us-usa-trump-impeachment-parnas/a-second-video-shows-trump-with-former-ukraine-fixer-lev-parnas-idUSKBN1ZT317
# 318 https://www.reuters.com/article/us-santander-orcel-breakup-specialreport/special-report-when-ana-ditched-andrea-the-saga-of-santander-idUSKBN1ZU0SZ
# 319 https://www.reuters.com/article/us-britain-eu-drugtrials-insight/on-eve-of-brexit-britain-faces-critical-test-to-defend-drug-trial-crown-idUSKBN1ZT0L3
# 320 https://www.reuters.com/article/us-balkans-economy-insight/struggling-state-owned-firms-hold-balkan-economies-back-idUSKBN1ZT0QQ
# 321 https://www.reuters.com/article/us-usa-fundraisers-scampacs-special-repo/special-report-scam-pac-fundraisers-reap-millions-in-the-name-of-heart-tugging-causes-idUSKBN1ZS28N
# 322 https://www.reuters.com/article/us-china-health-testing-insight/confusion-and-lost-time-how-testing-woes-slowed-chinas-coronavirus-response-idUSKBN1ZQ21K
# 323 https://www.reuters.com/article/us-mexico-oil-hedge-insight/mexico-goes-ghost-as-its-oil-hedge-bill-spirals-idUSKBN1ZM1JJ
# 324 https://www.reuters.com/article/us-hongkong-protests-arrestees-insight/arrested-hong-kong-protesters-stuck-in-limbo-as-cases-grind-forward-idUSKBN1ZM0LD
# 325 https://www.reuters.com/article/us-myanmar-rohingya-china-insight/china-struggles-in-new-diplomatic-role-trying-to-return-rohingya-to-myanmar-idUSKBN1ZJ0SY
# 326 https://www.reuters.com/article/us-usa-courts-secrecy-regulators-special/special-report-how-secrecy-in-u-s-courts-hobbles-regulators-idUSKBN1ZF1G9
# 327 https://www.reuters.com/article/us-gold-africa-refineries-insight/race-to-refine-the-bid-to-clean-up-africas-gold-rush-idUSKBN1ZE0YG
# 328 https://www.reuters.com/article/us-usa-fundraisers-scampacs-side/how-scam-pacs-fall-through-the-cracks-of-u-s-regulators-idUSKBN1ZS29B
# 329 https://www.reuters.com/article/us-india-citizenship-protests-kanhaiyaku/in-india-a-firebrands-anti-modi-mantra-resonates-at-nationwide-protests-idUSKBN1ZE0LI
# 330 https://www.reuters.com/article/us-gold-mining-artisanal-explainer/what-is-artisanal-gold-and-why-is-it-booming-idUSKBN1ZE0YU
# 331 https://www.reuters.com/article/us-usa-trade-supplychains-insight/u-s-bike-firms-face-uphill-slog-to-replace-chinese-supply-chains-idUSKBN1ZD1FV
# 332 https://www.reuters.com/article/us-china-aviation-comac-insight/chinas-bid-to-challenge-boeing-and-airbus-falters-idUSKBN1Z905N
# 333 https://www.reuters.com/article/us-hongkong-protests-journalists-insight/tear-gas-and-water-cannons-hong-kong-students-brave-the-front-lines-to-livestream-the-protests-idUSKBN1Z9001
# 334 https://www.reuters.com/article/us-indonesia-military-websites-insight/indonesian-army-wields-internet-news-as-a-weapon-in-papua-idUSKBN1Z7001
# 335 https://www.reuters.com/article/us-asml-holding-usa-china-insight/trump-administration-pressed-dutch-hard-to-cancel-china-chip-equipment-sale-sources-idUSKBN1Z50HN
# 336 https://www.reuters.com/article/us-iraq-security-soleimani-insight/inside-the-plot-by-irans-soleimani-to-attack-u-s-forces-in-iraq-idUSKBN1Z301Z
# 337 https://www.reuters.com/article/us-iraq-security-blast-legal-analysis/u-s-self-defense-argument-for-killing-soleimani-meets-skepticism-idUSKBN1Z301R
# 338 https://www.reuters.com/article/us-britain-eu-ireland-varadkar/british-eu-level-trade-playing-field-possible-but-difficult-irish-pm-idUSKBN1ZU1GA
# 339 https://www.reuters.com/article/us-britain-eu-fisheries/the-french-fishermen-who-could-sink-britains-post-brexit-ambitions-idUSKBN1ZT1YR
# 340 https://www.reuters.com/article/us-britain-eu-changes-explainer/explainer-through-the-brexit-looking-glass-what-changes-and-what-stays-the-same-idUSKBN1ZT2JH
# 341 https://www.reuters.com/article/us-britain-eu-challenges/new-dawn-brexit-to-do-list-money-charming-trump-and-making-friends-idUSKBN1ZT19M
# ...
# 605 https://www.reuters.com/article/us-soccer-england-women/manager-cushing-leaves-man-city-women-to-join-nycfc-idUSKBN1Z81UV
# 606 https://www.reuters.com/article/us-soccer-england-mun-china/manchester-united-sign-new-partnership-deal-with-alibaba-idUSKBN1YA143
# 607 https://www.reuters.com/article/us-soccer-spain-zozulya/rayo-albacete-game-marred-by-nazi-chants-to-finish-behind-closed-doors-idUSKBN1YV16A
# 608 https://www.reuters.com/article/us-soccer-spain-fcb-mad-protest/el-clasico-sparks-pro-independence-protests-near-barcelona-stadium-idUSKBN1YM21Y
# 609 https://www.reuters.com/article/us-soccer-spain-fcb-mad-preview/backdrop-of-protest-awaits-rescheduled-el-clasico-idUSKBN1YK0UU
# 610 https://www.reuters.com/article/us-soccer-italy-as-roma-ownership-factbo/factbox-ownership-of-leading-european-soccer-clubs-idUSKBN1YY0M8
# 611 https://www.reuters.com/article/us-soccer-italy-as-roma/as-roma-in-talks-over-sale-to-u-s-billionaire-friedkin-idUSKBN1YY0EZ
# 612 https://www.reuters.com/article/us-soccer-italy-mil-ibrahimovic/ibrahimovic-returns-to-ac-milan-on-six-month-deal-idUSKBN1YV1H7
# 613 https://www.reuters.com/article/us-soccer-germany-s04/schalke-boss-toennies-temporarily-steps-down-over-controversial-comments-idUSKCN1UX0HA
# 614 https://www.reuters.com/article/us-soccer-germany-ger-chl-report/germany-beat-chile-2-0-in-final-womens-world-cup-warmup-idUSKCN1T026L
# 615 https://www.reuters.com/article/us-soccer-germany-bay-sge/soccer-bayern-munich-win-bundesliga-title-for-seventh-successive-season-idUSKCN1SO0I3
# 616 https://www.reuters.com/article/us-soccer-france-homophobia/french-federation-head-stop-games-over-racist-chants-but-not-homophobic-ones-idUSKCN1VV1Z3
# 617 https://www.reuters.com/article/us-soccer-france-nce-olm/french-referee-praised-for-stopping-match-over-homophobic-banners-idUSKCN1VJ1ZD
# 618 https://www.reuters.com/article/us-soccer-france-psg-nim/neymar-to-miss-season-opener-for-paris-st-germain-idUSKCN1V00GU
# 619 https://www.reuters.com/article/us-soccer-mexico-mnt-ame/coach-mohamed-typifies-argentine-influence-on-mexican-soccer-idUSKBN1YW0FI
# 620 https://www.reuters.com/article/us-soccer-mexico-bonilla/soccer-2026-world-cup-could-lead-to-combined-north-american-league-liga-mx-chief-idUSKCN1MK1P1
# 621 https://www.reuters.com/article/us-soccer-mexico/america-coach-la-volpe-steps-down-after-string-of-losses-idUSKBN18311Z
# 622 https://www.reuters.com/article/icehockey-nhl-roundup/nhl-roundup-predators-finally-subdue-devils-in-shootout-idUSKBN1ZU0KT
# 623 https://www.reuters.com/article/us-tennis-ausopen-martinez/muguruza-must-take-command-against-kenin-says-coach-martinez-idUSKBN1ZU0YD
# 624 https://www.reuters.com/article/us-basketball-ncaa-roundup/top-25-roundup-ucla-takes-down-no-20-colorado-idUSKBN1ZU0V3
# 625 https://www.reuters.com/article/us-tennis-ausopen-kenin/confident-kenin-keen-to-take-the-fight-to-muguruza-idUSKBN1ZU0NR
# 626 https://www.reuters.com/article/us-tennis-ausopen-doubles/babos-and-mladenovic-win-australian-open-womens-doubles-idUSKBN1ZU0UC
# 627 https://www.reuters.com/article/us-basketball-nba-roundup/nba-roundup-raptors-defeat-cavs-for-ninth-straight-win-idUSKBN1ZU0UU
# 628 https://www.reuters.com/article/basketball-nba-lac-sac/fox-kings-rout-clippers-who-were-missing-leonard-idUSMTZXEG1VYK8BMN
# 629 https://www.reuters.com/article/basketball-nba-den-uta/nuggets-hold-off-jazz-despite-clarkson-eruption-idUSMTZXEG1VYK5SMM
# 630 https://www.reuters.com/article/basketball-nba-atl-phi/young-scores-39-as-hawks-topple-sixers-idUSMTZXEG1VYD1QFE
# 631 https://www.reuters.com/article/us-baseball-mlb-notebook/mlb-notebook-dodgers-dont-want-fake-banner-idUSKBN1ZP021
# 632 https://www.reuters.com/article/us-baseball-mlb-nym-degrom-alonso/mets-stars-go-to-bat-for-new-manager-rojas-idUSKBN1ZP00Y
# 633 https://www.reuters.com/article/us-baseball-mlb-lawsuit/lawsuit-from-fan-alleges-mlb-teams-engaged-in-corruption-in-sign-stealing-scandal-idUSKBN1ZN06H
# 634 https://www.reuters.com/article/us-tennis-ausopen-henin/grand-slam-experience-has-muguruza-primed-for-title-henin-idUSKBN1ZU0H2
# 635 https://www.reuters.com/article/us-tennis-ausopen-federer/imperious-djokovic-downs-federer-in-straight-sets-to-reach-final-idUSKBN1ZT19Q
# 636 https://www.reuters.com/article/icehockey-nhl-ari-lak/iafallo-hat-trick-leads-kings-past-coyotes-in-ot-idUSMTZXEG1VYHREL7
# 637 https://www.reuters.com/article/icehockey-nhl-njd-nsh/preds-beat-devils-in-shootout-to-cap-wild-affair-idUSMTZXEG1VYD30FF
# 638 https://www.reuters.com/article/icehockey-nhl-buf-mtl/montreal-beats-buffalo-for-third-straight-road-win-idUSMTZXEG1VYBB9DK
# 639 https://www.reuters.com/article/us-golf-phoenix-bryant/players-honor-bryant-at-tpc-scottsdales-iconic-16th-idUSKBN1ZU0BK
# 640 https://www.reuters.com/article/us-golf-phoenix-clark/clark-takes-phoenix-lead-with-best-score-of-pga-tour-career-idUSKBN1ZU08Y
# 641 https://www.reuters.com/article/us-football-nfl-superbowl-young-intervie/youthful-49ers-team-dont-even-know-how-good-they-are-former-quarterback-young-idUSKBN1ZN1NX
# 642 https://www.reuters.com/article/us-esports-soccer-fifa/esports-milan-to-host-fifa-eclub-world-cup-in-february-idUSKBN1ZE13L
# 643 https://www.reuters.com/article/us-olympics-ioc/olympics-games-must-connect-with-gamers-to-keep-olympics-relevant-bach-idUSKBN1Z91M2
# 644 https://www.reuters.com/article/us-motor-nascar-stewart/nascar-hall-of-fame-to-honor-stewarts-love-of-racing-idUSKBN1ZS30B
# 645 https://www.reuters.com/article/motor-nascar-baker/hall-of-fame-to-honor-bakers-vast-contributions-idUSKBN1ZK2SH
# 646 https://www.reuters.com/article/motor-nascar-labonte/bobby-labonte-lives-up-to-family-name-with-hall-induction-idUSKBN1ZG2D5
# 647 https://www.reuters.com/article/us-motor-f1-mercedes/daimler-ceo-dismisses-mercedes-f1-exit-speculation-idUSKBN1ZS30V
# 648 https://www.reuters.com/article/us-motor-f1-australia/formula-one-to-hold-auction-for-australian-bushfire-relief-idUSKBN1ZL16L
# 649 https://www.reuters.com/article/us-motor-f1-miami/f1-changes-planned-miami-gp-layout-after-local-opposition-idUSKBN1ZL02Z
# 650 https://www.reuters.com/article/football-nfl-superbowl-bloomberg/update-4-bloomberg-tackles-gun-violence-trump-touts-victories-in-super-bowl-ads-idUSL1N29Z0K6
# 651 https://www.reuters.com/article/us-cricket-nzl-eng-ban/spectator-who-racially-abused-archer-banned-for-two-years-idUSKBN1ZC2D7
# 652 https://www.reuters.com/article/us-australia-bushfires-cricket/australian-cricketers-paine-lyon-see-mind-blowing-fire-devastation-idUSKBN1Z8114
# 653 https://www.reuters.com/article/us-cricket-test-aus-nzl/head-trusts-officials-on-bushfire-smoke-in-sydney-test-idUSKBN1YZ0EU
# 654 https://www.reuters.com/article/us-sailing-australia/sailing-comanche-grabs-early-lead-after-slow-start-in-sydney-hobart-race-idUSKBN1YU0GS
# 655 https://www.reuters.com/article/us-sailing-sailgp/sailing-spain-sets-sights-on-sailgp-after-china-jumps-ship-idUSKBN1YL1QQ
# 656 https://www.reuters.com/article/sailing-sailgp/sailing-spain-sets-sights-on-sailgp-after-china-jumps-ship-idUSL8N28R45Y
# 657 https://www.reuters.com/article/us-rugby-union-england-borthwick/borthwick-to-join-leicester-as-head-coach-idUSKBN1ZK0Z0
# 658 https://www.reuters.com/article/us-rugby-union-super-savea/doctor-tiktok-ed-off-with-injured-all-blacks-loose-forward-savea-idUSKBN1ZK0WA
# 659 https://www.reuters.com/article/us-rugbyleague-tor-williams/rugby-all-blacks-williams-agrees-to-join-toronto-wolfpack-idUSKBN1XH2IQ
# 660 https://www.reuters.com/article/us-sport-athletics/world-indoor-champs-in-china-postponed-over-coronavirus-fears-idUSKBN1ZS2TV
# 661 https://www.reuters.com/article/sport-athletics/update-1-athletics-world-indoor-champs-in-china-postponed-over-coronavirus-fears-idUSL8N29Y73O
# 662 https://www.reuters.com/article/uk-sport-athletics/world-indoor-championships-in-china-postponed-over-coronavirus-fears-idUSKBN1ZS2TT
# 663 https://www.reuters.com/article/us-art-auction-impressionist-and-modern/lempicka-headlines-impressionist-auction-in-london-idUSKBN1ZT2MN
# 664 https://www.reuters.com/article/us-greece-britain-marbles/brexit-will-strengthen-european-support-for-return-of-parthenon-marbles-says-greek-minister-idUSKBN1ZT1XF
# 665 https://www.reuters.com/article/us-bulgaria-painter/blind-bulgarian-artist-finds-a-way-to-keep-painting-idUSKBN1ZQ1JK
# 666 https://www.reuters.com/article/us-sweden-theft/thieves-steal-dali-works-in-stockholm-smash-and-grab-raid-idUSKBN1ZT13M
# 667 https://www.reuters.com/article/us-philippines-volcano-artist/philippine-artist-paints-images-of-volcanic-devastation-using-ash-idUSKBN1ZN10O
# 668 https://www.reuters.com/article/us-germany-art-nazis/germany-returns-nazi-art-from-gurlitt-trove-to-french-family-idUSKBN1ZL24S
# 669 https://www.reuters.com/article/us-netherlands-art-van-gogh/disputed-van-gogh-self-portrait-is-genuine-dutch-research-finds-idUSKBN1ZJ1K8
# 670 https://www.reuters.com/article/us-senegal-art/pan-african-exhibition-seeks-to-herald-continents-art-scene-idUSKBN1ZG1IQ
# 671 https://www.reuters.com/article/us-italy-art-klimt/italy-confirms-long-lost-klimt-painting-hidden-in-wall-is-authentic-idUSKBN1ZG22N
# 672 https://www.reuters.com/article/us-france-protests-pensions-louvre/art-lovers-face-louvre-lock-out-as-staff-join-pension-strike-idUSKBN1ZG1HZ
# 673 https://www.reuters.com/article/us-pdvsa-debt/venezuelas-pdvsa-in-default-says-total-debt-remained-unchanged-in-2019-idUSKBN1ZQ1UM
# 674 https://www.reuters.com/article/us-swiss-snb/snb-seen-on-sidelines-as-virus-fears-push-swiss-franc-to-near-three-year-high-idUSKBN1ZQ0ZN
# 675 https://www.reuters.com/article/us-brazil-environment/brazil-to-create-amazon-council-to-protect-and-develop-the-rainforest-idUSKBN1ZK237
# 676 https://www.reuters.com/article/us-eu-telecoms-exclusive/eu-industry-chief-dismisses-fears-strict-security-rules-could-delay-5g-idUSKBN1ZI0H8
# 677 https://www.reuters.com/article/us-mexico-indigenous-artist/rebel-indigenous-mexican-weaver-talks-to-his-threads-idUSKBN1ZF02N
# 678 https://www.reuters.com/article/us-spain-court-picasso/banker-fined-58-million-for-smuggling-picasso-painting-out-of-spain-idUSKBN1ZF2AY
# 679 https://www.reuters.com/article/us-usa-holocaust/eyewitness-to-horror-new-york-museum-opens-exhibit-of-art-by-holocaust-victims-idUSKBN1ZE2R2
# 680 https://www.reuters.com/article/us-britain-royals-waxwork/madame-tussauds-removes-waxworks-of-harry-and-meghan-from-royal-family-display-idUSKBN1Z81WW
# 681 https://www.reuters.com/article/us-global-oil/oil-falls-1-as-investors-reassess-middle-east-risks-idUSKBN1Z6063
# 682 https://www.reuters.com/article/us-awards-oscars-billie-eilish/billie-eilish-to-give-special-performance-at-oscars-show-idUSKBN1ZS37S
# 683 https://www.reuters.com/article/us-film-birds-of-prey/margot-robbie-hints-at-more-female-action-movies-at-birds-of-prey-premiere-idUSKBN1ZS36I
# 684 https://www.reuters.com/article/us-britain-parsons/uk-broadcaster-nicholas-parsons-host-of-just-a-minute-dies-aged-96-idUSKBN1ZR1DO
# 685 https://www.reuters.com/article/us-film-queen-and-slim/director-matsoukas-says-queen-slim-debut-tells-story-of-my-people-idUSKBN1ZR2W0
# 686 https://www.reuters.com/article/us-canada-awards-juno/grammy-winner-cara-bags-most-nominations-in-canadas-2020-juno-awards-idUSKBN1ZR2GY
# 687 https://www.reuters.com/article/us-people-harvey-weinstein/ex-actress-says-weinstein-promised-her-movie-deal-in-exchange-for-threesome-idUSKBN1ZS1B2
# 688 https://www.reuters.com/article/us-awards-grammys/billie-eilish-sweeps-grammy-awards-with-top-four-prizes-idUSKBN1ZP0DA
# 689 https://www.reuters.com/article/us-usa-boxoffice/box-office-bad-boys-for-life-rules-over-the-gentlemen-idUSKBN1ZP0MU
# 690 https://www.reuters.com/article/us-people-harvey-weinstein/weinstein-accusers-ex-roommate-backs-up-sexual-assault-allegation-idUSKBN1ZR15F
# 691 https://www.reuters.com/article/us-people-harvey-weinstein/accuser-mimi-haleyi-says-weinstein-lunged-at-her-in-soho-apartment-idUSKBN1ZQ124
# 692 https://www.reuters.com/article/us-awards-grammys-ratings/grammy-awards-show-television-audience-dips-to-18-7-million-idUSKBN1ZQ2E4
# 693 https://www.reuters.com/article/us-awards-grammys-nipsey-hussle/rapper-nipsey-hussle-wins-two-posthumous-grammys-honored-in-tribute-performance-idUSKBN1ZQ0C4
# 694 https://www.reuters.com/article/us-awards-grammys-winners-factbox/factbox-key-winners-at-the-2020-grammy-awards-idUSKBN1ZQ0B3
# 695 https://www.reuters.com/article/us-awards-grammys-kobe-bryant/kobe-bryant-remembered-at-grammy-awards-hours-after-his-death-idUSKBN1ZQ02S
# 696 https://www.reuters.com/article/us-awards-grammys-nominations-factbox/factbox-key-nominations-for-the-2020-grammy-awards-idUSKBN1ZP0DI
# 697 https://www.reuters.com/article/us-spain-entertainment-goya-awards/pain-and-glory-wins-big-at-spains-goya-awards-idUSKBN1ZP01E
# 698 https://www.reuters.com/article/us-people-harvey-weinstein/actress-rosie-perez-backs-up-sciorra-account-in-weinstein-rape-trial-idUSKBN1ZN15O
# 699 https://www.reuters.com/article/us-awards-grammys-aerosmith/johnny-depp-jams-with-aerosmith-as-band-celebrates-50-year-career-idUSKBN1ZO0CT
# 700 https://www.reuters.com/article/us-australia-bushfires-pizza/lengthy-pizza-delivers-funds-for-embattled-australian-firefighters-idUSKBN1ZL0CR
# 701 https://www.reuters.com/article/us-mexico-beer-el-chapo/drink-like-a-mexican-kingpin-el-chapo-beer-launched-by-daughter-idUSKBN1ZG04Z
# 702 https://www.reuters.com/article/us-sport-trail-jornet/ultra-trail-runner-jornet-beats-base-jumper-in-odd-contest-idUSKBN1ZK2H4
# 703 https://www.reuters.com/article/us-japan-billionaire-maezawa/moonstruck-japanese-billionaires-girlfriend-entrants-top-20000-idUSKBN1ZF0HQ
# 704 https://www.reuters.com/article/us-odd-spotify-dogs/spotify-launches-playlists-for-dogs-left-home-alone-idUSKBN1ZE1D8
# 705 https://www.reuters.com/article/us-nissan-ghosn-yamaha/yamaha-warns-musicians-not-to-climb-in-instrument-cases-after-ghosn-escape-idUSKBN1ZD0O7
# 706 https://www.reuters.com/article/us-britain-politics-johnson-vegan/uks-johnson-i-need-to-lose-weight-but-becoming-vegan-would-cheese-me-off-idUSKBN1ZD0UT
# 707 https://www.reuters.com/article/us-britain-politics-psychic/after-britain-appeals-for-weirdos-spoon-bender-uri-geller-applies-idUSKBN1Z71JY
# 708 https://www.reuters.com/article/us-thailand-monk-cat/cat-vs-chants-friendly-feline-tests-buddhist-monks-patience-idUSKBN1Z20Z2
# 709 https://www.reuters.com/article/us-solar-eclipse-egg-standing/egg-standing-test-goes-viral-as-ring-of-fire-eclipse-crosses-asia-idUSKBN1YU0MZ
# 710 https://www.reuters.com/article/us-colorado-bankrobber/colorado-bank-robber-throws-cash-in-air-shouting-merry-christmas-idUSKBN1YT024
# 711 https://www.reuters.com/article/us-indonesia-cats/indonesian-housewife-tackles-homelessness-for-250-feral-cats-idUSKBN1YR1G5
# 712 https://www.reuters.com/article/us-usa-trade-wakanda/wakanda-free-trade-forever-fictional-nation-removed-from-u-s-trade-list-idUSKBN1YN0FN
# 713 https://www.reuters.com/article/us-new-year-japan-zodiac-window-cleaners/you-dirty-rat-zodiac-window-cleaners-set-tokyo-sparkling-for-new-year-idUSKBN1YN0MK
# 714 https://www.reuters.com/article/us-australia-weather-pork-roast/done-in-a-datsun-man-cooks-roast-pork-in-car-during-australian-heatwave-idUSKBN1YL0E5
# 715 https://www.reuters.com/article/us-philippines-athletics-odd/homemade-nikes-give-filipina-athlete-a-golden-edge-idUSKCN1YI03T
# 716 https://www.reuters.com/article/us-art-basel-artist/man-who-ate-120000-banana-at-art-show-says-im-not-sorry-idUSKBN1YD2F2
# 717 https://www.reuters.com/article/24-hours-in-pictures-30-jan-2020/top-photos-of-the-day-idUSRTS304P9
# 718 https://www.reuters.com/article/us-britain-eu-reaction/joy-and-sadness-how-the-world-is-reacting-on-brexit-day-idUSKBN1ZU0YZ
# 719 https://www.reuters.com/article/uk-britain-eu-markets/eu-checks-uk-compliance-with-market-rules-after-brexit-idUSKBN1ZU0ZD
# 720 https://www.reuters.com/article/us-ukraine-usa-pompeo-zelenskiy/pompeo-says-zelenskiy-white-house-visit-not-conditional-on-biden-probes-idUSKBN1ZU190
# Saving Indexer Config.....

# %% [markdown]
# ## 2.5 Index statistics

# %%
# load index, doc_lengths and doc_urls
with open('inverted_index.pickle', 'rb') as fp:
  index = pickle.load(fp)
with open('doc_lengths.pickle', 'rb') as fp:
  doc_lengths = pickle.load(fp)
with open('doc_urls.pickle', 'rb') as fp:
  doc_urls = pickle.load(fp)

# %%
print('Total index length', len(index))
print('\nTop terms by number of documents they apperared in:')
sorted_by_n_docs = sorted(index.items(), key=lambda kv: (len(kv[1]), kv[0]), reverse=True)
print([(sorted_by_n_docs[i][0], len(sorted_by_n_docs[i][1])) for i in range(20)])
print('\nTop terms by overall frequency:')
sorted_by_freq = sorted(index.items(), key=lambda kv: (kv[1][0], kv[0]), reverse=True)
print([(sorted_by_freq[i][0], sorted_by_freq[i][1][0]) for i in range(20)])
# Out:
# Total index length 13971
#
# Top terms by number of documents they apperared in:
# [('world', 721), ('use', 721), ('us', 721), ('unit', 721), ('tv', 721), ('thomson', 721), ('term', 721), ('tax', 721), ('state', 721), ('solut', 721), ('site', 721), ('see', 721), ('risk', 721), ('reuter', 721), ('quot', 721), ('privaci', 721), ('polit', 721), ('our', 721), ('newslett', 721), ('news', 721)]
#
# Top terms by overall frequency:
# [('reuter', 4970), ('s', 3521), ('said', 3026), ('thomson', 2172), ('all', 1910), ('more', 1617), ('delay', 1506), ('januari', 1486), ('have', 1473), ('advertis', 1456), ('solut', 1452), ('market', 1434), ('state', 1363), ('news', 1343), ('world', 1333), ('unit', 1233), ('govern', 1226), ('not', 1225), ('year', 1191), ('busi', 1146)]

# %% [markdown]
# # 3. Answering query

# %% [markdown]
# Now, given that we already have built the inverted index, it's time to utilize it for answering user queries. In this class there are two methods you need to implement:
# - `boolean_retrieval`, the simplest form of document retrieval which returns a set of documents such that each one contains all query terms. Returns a set of document ids. Refer to *ch.1* of the book for details;
# - `okapi_scoring`, Okapi BM25 ranking function - assigns scores to documents in the collection that are relevant to the user query. Returns a dictionary of scores, `doc_id:score`. Read about it in [Wikipedia](https://en.wikipedia.org/wiki/Okapi_BM25#The_ranking_function) and implement accordingly.
#
# Both methods accept `query` parameter in a form of a dictionary, `term:frequency`

# %%
from collections import Counter, OrderedDict
import math

class QueryProcessing:
    
    @staticmethod
    def prepare_query(raw_query):
        prep = Preprocessor()
        # pre-process query the same way as documents
        query = prep.preprocess(raw_query)
        # count frequency
        return Counter(query)
    
    @staticmethod
    def boolean_retrieval(query, index):
      """retrieve a set of documents containing all query terms"""
      
      #approach 1
      query_words = list(query.keys())
      result = [i[0] for i in index[query_words[0]][1:]]

      for word in query_words[1:]:
        if word not in index.keys():
          print(f"{word} not in any of indexed documents!!")
          continue
        word_documents_app = [i[0] for i in index[word][1:]]
        result = np.intersect1d(result, word_documents_app)
        if len(result) == 0 : 
          print("No article(s) containing all query terms")
          return None
      result = set(result)

      # #approach 2 : Use Set
      # result = set([i[1] for i in index[query_words[0]][1:]])
      # for word in list(query.keys())[1:]:
      #   word_documents_app = [i[1] for i in index.get(word,None)[1:]]
      #   if word_documents_app == None:
      #     print(f"{word} not found in any of indexed documents!!")
      #   else:
      #     result = result & set(word_documents_app)
        
      #   if len(result) == 0 : 
      #     print("No set of documnets containing all query terms")
      #     return None

      return result

    
    @staticmethod
    def okapi_scoring(query, doc_lengths, index, k1=1.2, b=0.75):
      """retrieve relevant documents with scores"""
      result_rank = {} #OrderedDict()
      N = len(doc_lengths) #total number of documents indexed
      avgdl = sum(doc_lengths.values())/N

      for doc_id in doc_lengths.keys():
        doc_len = doc_lengths.get(doc_id) #current document length

        for word in query.keys():
          word_in_doc = index.get(word,None)
          temp_word_idx = dict(word_in_doc[1:])
          tf = temp_word_idx.get(doc_id,None) # term frequency in current document
          if word_in_doc == None or tf == None: continue

          in_n_documents = len(word_in_doc[1:]) # the number of documents containing current query word
          idf = np.log((N-in_n_documents + 0.5)/(in_n_documents + 0.5)) # inverse document frequency

          main_fraction = ((k1 + 1) * tf) / ((k1 * ((1 - b) + b * (float(doc_len) / float(avgdl)))) + tf)

          if doc_id not in result_rank:
            result_rank[doc_id] = (idf * main_fraction)
          else:
            result_rank[doc_id] += (idf * main_fraction)

      #result_rank = sorted(result_rank.items(), key=lambda x: x[1],reverse=True)

      return result_rank

# %% [markdown]
# ## 3.1 Tests

# %%
test_doc_lengths = {1: 20, 2: 15, 3: 10, 4:20, 5:30}
test_index = {'x': [2, (1, 1), (2, 1)], 'y': [2, (1, 1), (3, 1)], 'z': [3, (2, 1), (4,2)]}


test_query1 = QueryProcessing.prepare_query('x z')
test_query2 = QueryProcessing.prepare_query('x y')


assert QueryProcessing.boolean_retrieval(test_query1, test_index) == {2}
assert QueryProcessing.boolean_retrieval(test_query2, test_index) == {1}
okapi_res = QueryProcessing.okapi_scoring(test_query2, test_doc_lengths, test_index)
assert all(k in okapi_res for k in (1,2,3))
assert not any(k in okapi_res for k in (4,5))
assert okapi_res[1] > okapi_res[3] > okapi_res[2]

# %%
okapi_res
# Out:
# {1: 0.6587606318860281, 2: 0.3681816620619555, 3: 0.41734538548269146}

# %%
test_query1 = QueryProcessing.prepare_query('Organize engine')
r2 = QueryProcessing.boolean_retrieval(test_query1, index)

# %% [markdown]
# # 4. Setting up a server

# %% [markdown]
# **Bonus task \*** Organize the resulting search engine as a web-service that gets a query from get-parameters and returns urls with scores as a `json` dictionary. Check its work in a browser of with curl, should look smth like this:
#
# `> curl localhost:8080/?q=some_query_text
# { "url1" : 0.9, "url2": 0.8 }`
#
# You can use one of the following tools for this task: https://www.acmesystems.it/python_http, http.server.ThreadingHTTPServer (3.7+) https://docs.python.org/3/library/http.server.html#http.server.SimpleHTTPRequestHandler

# %%
#TODO write a web-service that answers queries using inverted index
